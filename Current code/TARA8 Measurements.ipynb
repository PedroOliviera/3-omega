# %% [markdown]
# # TARA8 Measurements
# ## 2019-08-22 Pedro Oliveira

# %%
import lck_tools as lck
from tc3omega.datareader import Data  # reads data from .csv
from tc3omega.constants import Constants  # read sample data from .yml
from tc3omega.analysis import Analyzer  # fits linear approx. or 2D model
from tc3omega.logmaker import Logmaker  # creates plots and log files
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import serial
import os

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan2-2019-08-22',direc)
lclist=[ 500,  750, 1000, 1250, 1600, 2000, 2500, 3000, 3700]

# %%
lclist=[ 500,  750, 1000, 1250, 1600, 2000, 2500, 3000, 3700]

output = lck.fullScan(lclist,20000,30,scan_v_or_f='freq',stb_time=9,averaged_time=3,n_sweeps=20,lc_const=[3],direc=direc)
# Out:
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 108 seconds
#
# scanning whole range
#
# For:   500Hz
# x:
# [-0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
#  -0.00099183 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
# ...

# %%
lck.beep()
lck.beep()
lck.beep()

# %%
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-5',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-5_analysis',data4ped,title4ped,direc=direc)

direc = r'C:\Users\Pedro\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Ara_tc3omega\TARA8'

lck.csv_writer('TARA8-SiOx-5',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-5_analysis',data4ped,title4ped,direc=direc)

# %%
freq = data4ara[0]
v3w = data4ara[1]

fig = plt.figure()
plt.errorbar(np.log(freq),v3w,fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
v3w = data4ped[1]
v3 = np.array([])
for v in v3w:
    if v != 0 and v != np.isnan(v):
        v3 = np.append(v3,v)
num_points = len(freq)
n_sweeps = int(len(v3)/num_points)

fig = plt.figure(figsize=(20,8))
plt.xticks(range(num_points))
for sweep in range(n_sweeps):
    plt.errorbar(np.log(freq),v3[sweep*num_points:(sweep + 1)*(num_points)],fmt='o')

# %%
from tc3omega.datareader import Data
from tc3omega.constants import Constants
from tc3omega.analysis import Analyzer
from tc3omega.logmaker import Logmaker
import os
direc = r'C:\Users\Pedro\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Ara_tc3omega\TARA8'
os.chdir(direc)
kappas0 = np.array([1.5, 130., 1.5], dtype=np.double)  # use np.double!
fit_indices = [0, 1, 2]


constants = Constants.fromFile('siox_si_siox.txt').getvals()
data = Data('TARA8-SiOx-5.csv')
constants['heater_dRdT']= 0.09
A = Analyzer(constants, data, kappas0, fit_indices,
             boundary_typ='isothermal', use_substrate_guess=True)

eq_layers = [(0,2)]

fit_kappas = A.MCfit2D(N=100, equivalent_layers=eq_layers)

print('2D Model: ')
print("fitted thermal conductivities for layers\n{}:"
      .format(A.layer_names))
print()
print("fitted values of these layers:\n{}"
      .format(fit_kappas))
print()
print("fit residual: ", A.F_last)
print()
print()
print()
LogA = Logmaker(A)

# plot latest result in 'A'
LogA.make_MCfit_plot()

k_film, k_sub = A.LinApproxFit(const_eta=None)
print("Linear approximation:  ")
print("film thermal conductivity: {:.2f}".format(k_film))
print()
print("substrate thermal conductivity: {:.2f}".format(k_sub))
print()
LogA = Logmaker(A)
LogA.make_LAfit_plot()
# Out:
# 2D Model:
# fitted thermal conductivities for layers
# ['silicon_oxide1', 'silicon', 'silicon_oxide2']:
#
# fitted values of these layers:
# [ 1.43566579 78.33474211  1.43566579]
#
# fit residual:  6.463692918155153e-08
#
#
#
# Linear approximation:
# film thermal conductivity: 1.59
#
# substrate thermal conductivity: 76.76

# %%
output = lck.fullScan(lclist,20000,30,scan_v_or_f='freq',stb_time=9,averaged_time=3,n_sweeps=5,lc_const=[2,2.25,2.5,2.75],direc=direc)
# Out:
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2
# estimated time for scan: 108 seconds
#
# scanning whole range
#
# For:   500Hz
# x:
# [-0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
#  -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183 -0.00029183
# ...

# %%
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-5',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-5_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-5',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-5_analysis',data4ped,title4ped,direc=direc)

# %%
os.chdir(direc)

data = pd.read_csv("TARA8-SiOx-5_analysis.csv")

# %%
import graphing

graph_multivolt('TARA8-SiOx-5_analysis.csv')
# Out:
# Voltage: 2.0
# film thermal conductivity: 2.19
# substrate thermal conductivity: 82.43
#
# Voltage: 2.25
# film thermal conductivity: 3.15
# substrate thermal conductivity: 127.70
#
# Voltage: 2.5
# film thermal conductivity: 4.59
# substrate thermal conductivity: 171.28
#
# Voltage: 2.75
# film thermal conductivity: 6.33
# substrate thermal conductivity: 229.93

# %%
v3w = data4ped[1]
v3 = np.array([])
for v in v3w:
    if v != 0 and v != np.isnan(v):
        v3 = np.append(v3,v)
num_points = len(freq)
n_sweeps = int(len(v3)/num_points)

fig = plt.figure(figsize=(20,8))
plt.xticks(range(num_points))
for sweep in range(n_sweeps):
    plt.errorbar(np.log(freq),v3[sweep*num_points:(sweep + 1)*(num_points)],fmt='o')

# %% [markdown]
# I wish i did it at 3V too for comparison

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan2-2019-08-22',direc)
output = lck.fullScan(lclist,20000,30,scan_v_or_f='freq',stb_time=9,averaged_time=3,n_sweeps=5,lc_const=[3],direc=direc)
# Out:
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 108 seconds
#
# scanning whole range
#
# For:   500Hz
# x:
# [-0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00099183 -0.00099183 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183
#  -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00099183 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
#  -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992 -0.00098992
# ...

# %%
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-7',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-7_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-7',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-7_analysis',data4ped,title4ped,direc=direc)

# %%
os.chdir(direc)
graph_multivolt('TARA8-SiOx-7_analysis.csv')
# Out:
# Voltage: 3
# film thermal conductivity: 1.99
# substrate thermal conductivity: 93.42

# %%
x, _ = lck.mn_scans(lclist,harm=1,averaged_time=3,n_sweeps=5,lc_const=3,direc=direc)
# Out:
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 108 seconds
#
# scanning whole range
#
# For:   500Hz
# x:
# [0.7974281 0.7974281 0.7974281 0.7974281 0.7974281 0.7974281 0.7974281
#  0.7974281 0.7974281 0.7974281 0.7974281 0.7974281 0.7974281 0.7974281
#  0.7974281 0.7974281 0.7974281 0.7974281 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
#  0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892 0.7974892
# ...

# %%
direc = r'C:\Users\Pedro\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Current code'
os.chdir(direc)
    
import python_sample
# Out:
# running...
# do you want to preset? (y/n). Make sure BNCs are set before enteringn
# Press enter to start measurement
# Measuring...
# press enter to stop measurement
# press enter to start shunt measurement or n to cancel
# measuring...
# Done measurement

# %% [markdown]
# bad idea...

# %%
# %run python_sample
# Out:
# running...
# do you want to preset? (y/n). Make sure BNCs are set before enteringn
# Press enter to start measurementn
# Measuring...
# press enter to stop measurementn

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan2-2019-08-22',direc)
output = lck.fullScan(500,3700,5,scan_v_or_f='freq',stb_time=9,averaged_time=2,n_sweeps=2,lc_const=[2.5,2.75,3],direc=direc)
# Out:
# 0.5003700000525311
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2.5
# estimated time for scan: 55 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00056076 -0.00056076 -0.00056076 -0.00055886 -0.00055886 -0.00055886
#  -0.00055886 -0.00055886 -0.00055886 -0.00055886 -0.00055886 -0.00055886
#  -0.00055886 -0.00055886 -0.00055886 -0.00055886]
# output mean:  -0.00055921451875
#
# out_x:
# -0.00055921451875
#
#
# For:   824.6657052629091Hz
# x:
# [-0.00053978 -0.00053978 -0.00053978 -0.00053978 -0.00053978 -0.00053978
#  -0.00053978 -0.00053978 -0.00053978 -0.00053978 -0.00053978 -0.00053978
#  -0.00053978 -0.00053978 -0.00053978 -0.00053978]
# output mean:  -0.0005397834
#
# out_x:
# -0.0005397834
#
#
# For:   1360.147050873544Hz
# x:
# [-0.00052452 -0.00052452 -0.00052452 -0.00052452 -0.00052452 -0.00052452
#  -0.00052452 -0.00052452 -0.00052452 -0.00052452 -0.00052452 -0.00052452
# ...

# %% [markdown]
# # Garbage data

# %%
# garbage data

direc = r'C:\Users\Pedro\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Current code'
os.chdir(direc)
import graphing
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'
os.chdir(direc)

title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

os.chdir(direc)
graphing.graph_multivolt('TARA8-SiOx-8_analysis.csv')
# Out:
# Voltage: 2.5
# film thermal conductivity: 1.68
# substrate thermal conductivity: 132.38
#
# Voltage: 2.75
# film thermal conductivity: 2.10
# substrate thermal conductivity: 210.51
#
# Voltage: 3.0
# film thermal conductivity: 2.08
# substrate thermal conductivity: 146.88
#
# heater dRdT used:
# 0.09

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-22',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[3],direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.0009842 -0.0009842 -0.0009842 -0.0009842 -0.0009842 -0.0009842
#  -0.0009842 -0.0009842]
# output mean:  -0.0009841993
#
# out_x:
# -0.0009841993
#
#
# For:   974.347580187329Hz
# x:
# [-0.00093651 -0.00093651 -0.00093842 -0.00093842 -0.00093842 -0.00093842
#  -0.00093842 -0.00093842]
# output mean:  -0.0009379424499999999
#
# out_x:
# -0.0009379424499999999
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646
#  -0.00089646 -0.00089646]
# output mean:  -0.0008964576
#
# out_x:
# -0.0008964576
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877
#  -0.00084877 -0.00084877]
# output mean:  -0.0008487739
#
# out_x:
# -0.0008487739
#
#
# done scanning
# ...

# %%
graphing.graph_multivolt([output[i] for i in range(1,len(output))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-26cfca2512b3> in <module>
# ----> 1 graphing.graph_multivolt([output[i] for i in range(1,len(output))])
#
# ~\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Current code\graphing.py in graph_multivolt(data)
#      39
#      40         freqs = check_zeros(freqs)
# ---> 41         v3w = check_zeros(v3w)
#      42         v1w = check_zeros(v1w)
#      43         v3w_avg = check_zeros(v3w_avg)
#
# ~\Dropbox\1-Three Omega with Ara\new_python\3omega-lockin-Pedro\Current code\graphing.py in check_zeros(datas)
#      12         '''makes sure any dataset parameter does not contain 0 or NaN'''
#      13         for i,dat in enumerate(datas):
# ---> 14                 if np.isnan(dat) or dat == 0:
#      15                         datas = datas[:i]
#      16                         return datas
#
# ...

# %% [markdown]
# #

# %%
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

graphing.graph_multivolt('TARA8-SiOx-8_analysis.csv')
# Out:
# Voltage: 3
# film thermal conductivity: 1.54
# substrate thermal conductivity: 131.50
#
# heater dRdT used:
# 0.09

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-22',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[3],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

os.chdir(direc)
graphing.graph_multivolt('TARA8-SiOx-8_analysis.csv')
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229
#  -0.00098229 -0.00098229]
# output mean:  -0.000982292
#
# out_x:
# -0.000982292
#
#
# For:   974.347580187329Hz
# x:
# [-0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651
#  -0.00093651 -0.00093651]
# output mean:  -0.0009365119
#
# out_x:
# -0.0009365119
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646
#  -0.00089646 -0.00089646]
# output mean:  -0.0008964576
#
# out_x:
# -0.0008964576
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877
#  -0.00084877 -0.00084877]
# output mean:  -0.0008487739
#
# out_x:
# -0.0008487739
#
#
# done scanning
# ...

# %%
direc =  r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8/TARA8_Scan3-2019-08-22()

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-22',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[3],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

os.chdir(direc)
graphing.graph_multivolt('TARA8-SiOx-8_analysis.csv')
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229
#  -0.00098229 -0.00098229]
# output mean:  -0.000982292
#
# out_x:
# -0.000982292
#
#
# For:   974.347580187329Hz
# x:
# [-0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651
#  -0.00093651 -0.00093651]
# output mean:  -0.0009365119
#
# out_x:
# -0.0009365119
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646
#  -0.00089646 -0.00089646]
# output mean:  -0.0008964576
#
# out_x:
# -0.0008964576
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877 -0.00084877
#  -0.00084877 -0.00084877]
# output mean:  -0.0008487739
#
# out_x:
# -0.0008487739
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8/TARA8_Scan3-2019-08-22(1)'
lck.csv_writer('TARA8-SiOx-8',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-8_analysis',data4ped,title4ped,direc=direc)

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[3],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-9',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-9_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-9',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-9_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00098038 -0.00098038 -0.00098038 -0.00098038 -0.00098038 -0.00098038
#  -0.00098038 -0.00098038]
# output mean:  -0.0009803846
#
# out_x:
# -0.0009803846
#
#
# For:   974.347580187329Hz
# x:
# [-0.0009346  -0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651
#  -0.00093651 -0.0009346 ]
# output mean:  -0.000936035075
#
# out_x:
# -0.000936035075
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646 -0.00089646
#  -0.00089646 -0.00089646]
# output mean:  -0.0008964576
#
# out_x:
# -0.0008964576
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00083352 -0.00083352 -0.00083542 -0.00083733 -0.00083924 -0.00084114
#  -0.00084114 -0.00084305]
# output mean:  -0.0008380450375
#
# out_x:
# -0.0008380450375
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[2.5],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-9',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-9_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-10',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-10_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2.5
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00055695 -0.00055695 -0.00055695 -0.00055695 -0.00055695 -0.00055695
#  -0.00055695 -0.00055695]
# output mean:  -0.0005569495
#
# out_x:
# -0.0005569495
#
#
# For:   974.347580187329Hz
# x:
# [-0.00053215 -0.00053215 -0.00053215 -0.00053215 -0.00053215 -0.00053215
#  -0.00053215 -0.00053215]
# output mean:  -0.000532154
#
# out_x:
# -0.000532154
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00051117 -0.00051117 -0.00050927 -0.00050927 -0.00050736 -0.00050736
#  -0.00050736 -0.00050736]
# output mean:  -0.000508789
#
# out_x:
# -0.000508789
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00049019 -0.00049019 -0.00049019 -0.00049019 -0.00049019 -0.00049019
#  -0.00049019 -0.00049019]
# output mean:  -0.0004901923
#
# out_x:
# -0.0004901923
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[2.5],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-10',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-10_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-10',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-10_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2.5
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00055695 -0.00055886 -0.00055886 -0.00055886 -0.00055886 -0.00055886
#  -0.00056076 -0.00056076]
# output mean:  -0.0005590953
#
# out_x:
# -0.0005590953
#
#
# For:   974.347580187329Hz
# x:
# [-0.00053406 -0.00053406 -0.00053406 -0.00053406 -0.00053406 -0.00053406
#  -0.00053406 -0.00053406]
# output mean:  -0.0005340613
#
# out_x:
# -0.0005340613
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00051499 -0.00051499 -0.00051499 -0.00051499 -0.00051499 -0.00051499
#  -0.00051499 -0.00051499]
# output mean:  -0.0005149879
#
# out_x:
# -0.0005149879
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00048828 -0.00048828 -0.00048828 -0.00048828 -0.00048828 -0.00048828
#  -0.00048828 -0.00048828]
# output mean:  -0.000488285
#
# out_x:
# -0.000488285
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[2.5],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-11',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-11_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-11',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-11_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2.5
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00055886 -0.00055886 -0.00055886 -0.00055886 -0.00055886 -0.00055886
#  -0.00055886 -0.00056076]
# output mean:  -0.0005590953125
#
# out_x:
# -0.0005590953125
#
#
# For:   974.347580187329Hz
# x:
# [-0.00053406 -0.00053406 -0.00053406 -0.00053406 -0.00053406 -0.00053406
#  -0.00053406 -0.00053406]
# output mean:  -0.0005340613
#
# out_x:
# -0.0005340613
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00051499 -0.00051499 -0.00051499 -0.00051499 -0.00051499 -0.00051499
#  -0.00051499 -0.00051499]
# output mean:  -0.0005149879
#
# out_x:
# -0.0005149879
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00048828 -0.00048828 -0.00048638 -0.00048638 -0.00048638 -0.00048638
#  -0.00048638 -0.00048638]
# output mean:  -0.0004868531
#
# out_x:
# -0.0004868531
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[2.75],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-12',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-12_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-12',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-12_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 2.75
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00074387 -0.00074387 -0.00074387 -0.00074387 -0.00074387 -0.00074387
#  -0.00074387 -0.00074387]
# output mean:  -0.0007438697
#
# out_x:
# -0.0007438697
#
#
# For:   974.347580187329Hz
# x:
# [-0.00071335 -0.00071335 -0.00071335 -0.00071335 -0.00071144 -0.00071144
#  -0.00071144 -0.00071144]
# output mean:  -0.0007123984500000001
#
# out_x:
# -0.0007123984500000001
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00068474 -0.00068474 -0.00068474 -0.00068474 -0.00068474 -0.00068474
#  -0.00068665 -0.00068665]
# output mean:  -0.000685218725
#
# out_x:
# -0.000685218725
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.0006485 -0.0006485 -0.0006485 -0.0006485 -0.0006485 -0.0006485
#  -0.0006485 -0.0006485]
# output mean:  -0.0006485023
#
# out_x:
# -0.0006485023
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[3.25],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-13',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-13_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-13',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-13_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3.25
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00125123 -0.00125123 -0.00125123 -0.00125123 -0.00125123 -0.00125123
#  -0.00125123 -0.00125123]
# output mean:  -0.001251228
#
# out_x:
# -0.001251228
#
#
# For:   974.347580187329Hz
# x:
# [-0.00119401 -0.00119401 -0.00119401 -0.00119401 -0.00119401 -0.00119401
#  -0.00119401 -0.00119401]
# output mean:  -0.001194008
#
# out_x:
# -0.001194008
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00113869 -0.00113869 -0.00113869 -0.00113869 -0.0011406  -0.0011406
#  -0.0011406  -0.0011406 ]
# output mean:  -0.0011396484999999998
#
# out_x:
# -0.0011396484999999998
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00108338 -0.00108338 -0.00108338 -0.00108338 -0.00108338 -0.00108338
#  -0.00108338 -0.00108338]
# output mean:  -0.001083381
#
# out_x:
# -0.001083381
#
#
# done scanning
# ...

# %%
direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/TARA8'
direc = lck.create_folder('TARA8_Scan3-2019-08-23',direc)
output = lck.fullScan(500,3700,4,scan_v_or_f='freq',stb_time=1,averaged_time=1,n_sweeps=1,lc_const=[2.75],direc=direc)
title4ara = ['freq','Vs_3w','Vs_1w','Vs_1w_o','Vsh_1w']
title4ped = ['freq','v3w','v3w_avg','v1w','v1w_sh','volt']

data4ara = output[0]
data4ped = [output[i] for i in range(1,len(output))]

lck.csv_writer('TARA8-SiOx-14',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-14_analysis',data4ped,title4ped,direc=direc)

direc = r'C:/Users/Pedro/Dropbox/1-Three Omega with Ara/new_python/3omega-lockin-Pedro/Ara_tc3omega/TARA8'

lck.csv_writer('TARA8-SiOx-14',data4ara,title4ara,direc=direc)
lck.csv_writer('TARA8-SiOx-14_analysis',data4ped,title4ped,direc=direc)
# Out:
# 0.6671600000700414
# make sure BNCs are set to sample
# Starting sweep number: 1
# Voltage: 3
# estimated time for scan: 8 seconds
#
# scanning whole range
#
# For:   499.99999999999983Hz
# x:
# [-0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229 -0.00098229
#  -0.00098229 -0.00098229]
# output mean:  -0.000982292
#
# out_x:
# -0.000982292
#
#
# For:   974.347580187329Hz
# x:
# [-0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651 -0.00093651
#  -0.00093651 -0.00093651]
# output mean:  -0.0009365119
#
# out_x:
# -0.0009365119
#
#
# For:   1898.7064140338057Hz
# x:
# [-0.00089264 -0.00089264 -0.00089264 -0.00089264 -0.00089264 -0.00089264
#  -0.00089264 -0.00089264]
# output mean:  -0.0008926429
#
# out_x:
# -0.0008926429
#
#
# For:   3699.9999999999995Hz
# x:
# [-0.00084496 -0.00084496 -0.00084496 -0.00084496 -0.00084496 -0.00084496
#  -0.00084496 -0.00084496]
# output mean:  -0.0008449592
#
# out_x:
# -0.0008449592
#
#
# done scanning
# ...

# %% [markdown]
# I Did above 3 times...
